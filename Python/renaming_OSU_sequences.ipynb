# %%
import os

# %%
sample_names = []
count = 0
directory = '../../Adam Cobb/Sequencing_output/rawdata/sample_fastq/AMF/duplicates/'
for file in os.listdir(directory):
    file_split = file.split('_')[0]
    if (count%4 == 0) | (count%4 == 1):
        os.rename(directory + file, '../../Adam Cobb/Sequencing_output/rawdata/sample_fastq/AMF/AMF1/' + file)
    count += 1

#     file_split = file.split('.')
    
#     new_name = file_split[1] + '_' + file_split[3] + '_' + 'L001' + '_' + file_split[7] + '_001.fastq'
#     os.rename(directory + file, directory + new_name)

# %%
0%4
# Out:
# 0

# %%
sample_names
# Out:
# ['A22',
#  'A22',
#  'A22',
#  'A22',
#  'A23',
#  'A23',
#  'A23',
#  'A23',
#  'A24',
#  'A24',
#  'A24',
#  'A24',
#  'A25',
#  'A25',
#  'A25',
#  'A25',
#  'A26',
#  'A26',
#  'A26',
#  'A26',
#  'A27',
#  'A27',
#  'A27',
#  'A27',
#  'A29',
#  'A29',
#  'A29',
#  'A29',
#  'A30',
#  'A30',
#  'A30',
#  'A30',
#  'A31',
#  'A31',
#  'A31',
#  'A31',
#  'A32',
#  'A32',
#  'A32',
#  'A32',
#  'A34',
#  'A34',
#  'A34',
#  'A34',
#  'A35',
#  'A35',
#  'A35',
#  'A35',
#  'A36',
#  'A36',
#  'A36',
#  'A36',
#  'A37',
#  'A37',
#  'A37',
#  'A37',
#  'A38',
#  'A38',
#  'A38',
#  'A38',
#  'A40',
#  'A40',
#  'A40',
#  'A40',
#  'A41',
#  'A41',
#  'A41',
#  'A41',
#  'A42',
#  'A42',
#  'A42',
#  'A42',
#  'A43',
#  'A43',
#  'A43',
#  'A43',
#  'A45',
#  'A45',
#  'A45',
#  'A45',
#  'A46',
#  'A46',
#  'A46',
#  'A46',
#  'A47',
#  'A47',
#  'A47',
#  'A47',
#  'A48',
#  'A48',
#  'A48',
#  'A48',
#  'A49',
#  'A49',
#  'A49',
#  'A49',
#  'B1',
#  'B1',
#  'B1',
#  'B1',
# ...
